# %%
import re
from graphviz import Digraph

# Define the input data as a multi-line string
input_data = """
Recipe 1: Water + Fire = Steam
New Item: Steam

Recipe 2: Water + Earth = Mud
New Item: Mud

Recipe 3: Fire + Earth = Lava
New Item: Lava

Recipe 4: Wind + Earth = Dust
New Item: Dust

Recipe 5: Water + Wind = Rain
New Item: Rain

Recipe 6: Fire + Wind = Smoke
New Item: Smoke

Recipe 7: Steam + Earth = Geyser
New Item: Geyser

Recipe 8: Mud + Fire = Clay
New Item: Clay

Recipe 9: Mud + Wind = Sand
New Item: Sand

Recipe 10: Rain + Earth = Plant
New Item: Plant

Recipe 11: Rain + Fire = Rainbow
New Item: Rainbow

Recipe 12: Rain + Wind = Storm
New Item: Storm

Recipe 13: Lava + Water = Obsidian
New Item: Obsidian

Recipe 14: Lava + Wind = Ash
New Item: Ash

Recipe 15: Lava + Earth = Volcano
New Item: Volcano

Recipe 16: Dust + Water = Mud
New Item: Mud

Recipe 17: Dust + Fire = Ash
New Item: Ash

Recipe 18: Dust + Wind = Sandstorm
New Item: Sandstorm

Recipe 19: Smoke + Water = Cloud
New Item: Cloud

Recipe 20: Smoke + Earth = Ash
New Item: Ash

Recipe 21: Smoke + Wind = Fog
New Item: Fog

Recipe 22: Plant + Water = Tree
New Item: Tree

Recipe 23: Plant + Fire = Ash
New Item: Ash

Recipe 24: Plant + Earth = Forest
New Item: Forest

Recipe 25: Plant + Wind = Seeds
New Item: Seeds

Recipe 26: Clay + Fire = Pottery
New Item: Pottery

Recipe 27: Clay + Wind = Sand
New Item: Sand

Recipe 28: Clay + Earth = Brick
New Item: Brick

Recipe 29: Sand + Water = Quicksand
New Item: Quicksand

Recipe 30: Sand + Fire = Glass
New Item: Glass

Recipe 31: Sand + Wind = Dune
New Item: Dune

Recipe 32: Tree + Water = Forest
New Item: Forest

Recipe 33: Tree + Fire = Charcoal
New Item: Charcoal

Recipe 34: Tree + Earth = Forest
New Item: Forest

Recipe 35: Tree + Wind = Leaves
New Item: Leaves

Recipe 36: Forest + Fire = Wildfire
New Item: Wildfire

Recipe 37: Forest + Wind = Leaves
New Item: Leaves

Recipe 38: Forest + Earth = Jungle
New Item: Jungle

Recipe 39: Glass + Water = Frosted Glass
New Item: Frosted Glass

Recipe 40: Glass + Earth = Crystal
New Item: Crystal

Recipe 41: Glass + Wind = Sandstorm
New Item: Sandstorm

Recipe 42: Obsidian + Fire = Magma
New Item: Magma

Recipe 43: Obsidian + Earth = Rock
New Item: Rock

Recipe 44: Obsidian + Wind = Shard
New Item: Shard

Recipe 45: Rock + Water = Pebble
New Item: Pebble

Recipe 46: Rock + Fire = Lava
New Item: Lava

Recipe 47: Rock + Earth = Mountain
New Item: Mountain

Recipe 48: Rock + Wind = Sand
New Item: Sand

Recipe 49: Ash + Water = Mud
New Item: Mud

Recipe 50: Ash + Earth = Fertilizer
New Item: Fertilizer

Recipe 51: Ash + Wind = Soot
New Item: Soot

Recipe 52: Cloud + Fire = Lightning
New Item: Lightning

Recipe 53: Cloud + Earth = Fog
New Item: Fog

Recipe 54: Cloud + Wind = Storm
New Item: Storm

Recipe 55: Fog + Water = Cloud
New Item: Cloud

Recipe 56: Fog + Fire = Steam
New Item: Steam

New Item: Geothermal Spring

Recipe 166: Wind + Groundwater = Artesian Well
New Item: Artesian Well

Recipe 167: Earth + Reservoir = Basin
New Item: Basin

Recipe 168: Water + Basin = Lake
New Item: Lake

Recipe 169: Fire + Basin = Dry Basin
New Item: Dry Basin

Recipe 170: Wind + Basin = Depression
New Item: Depression

Recipe 171: Earth + Lake = Island
New Item: Island

Recipe 172: Water + Lake = Lagoon
New Item: Lagoon

Recipe 173: Fire + Lake = Steam
New Item: Steam

Recipe 174: Wind + Lake = Wave
New Item: Wave

Recipe 175: Earth + Lagoon = Reef
New Item: Reef

Recipe 176: Water + Reef = Coral
New Item: Coral

Recipe 177: Fire + Reef = Ash
New Item: Ash

Recipe 178: Wind + Reef = Whirl
New Item: Whirl

Recipe 179: Earth + Coral = Limestone
New Item: Limestone

Recipe 180: Water + Limestone = Karst
New Item: Karst

Recipe 181: Fire + Limestone = Quicklime
New Item: Quicklime

Recipe 182: Wind + Limestone = Dust
New Item: Dust

Recipe 183: Earth + Karst = Cave
New Item: Cave

Recipe 184: Water + Karst = Geyser
New Item: Geyser

Recipe 185: Fire + Karst = Magma Chamber
New Item: Magma Chamber

Recipe 186: Wind + Karst = Blowhole
New Item: Blowhole

Recipe 187: Earth + Geyser = Hot Spring
New Item: Hot Spring

Recipe 188: Water + Geyser = Fountain
New Item: Fountain

Recipe 189: Fire + Geyser = Steam Vent
New Item: Steam Vent

Recipe 190: Wind + Geyser = Mist
New Item: Mist

Recipe 191: Earth + Spring = Oasis
New Item: Oasis

Recipe 192: Water + Spring = Fountain
New Item: Fountain

Recipe 193: Fire + Spring = Steam Vent
New Item: Steam Vent

Recipe 194: Wind + Spring = Cool Breeze
New Item: Cool Breeze

Recipe 195: Earth + Fountain = Monument
New Item: Monument

Recipe 196: Water + Monument = Waterfall
New Item: Waterfall

Recipe 197: Fire + Monument = Eternal Flame
New Item: Eternal Flame

Recipe 198: Wind + Monument = Pillar of Wind
New Item: Pillar of Wind

Recipe 199: Earth + Waterfall = River
New Item: River

Recipe 200: Water + River = Stream
New Item: Stream
"""

# Extract recipes from the input data
recipes = re.findall(r"Recipe \d+: ([\w ]+) \+ ([\w ]+) = ([\w ]+)", input_data)

# Create a Graphviz digraph
dot = Digraph(comment='Combination Game Recipes')

# Add nodes and edges to the digraph
for idx, (a, b, c) in enumerate(recipes, 1):
    recipe_node = f'Recipe{idx}'
    dot.node(recipe_node, shape='box')
    dot.edge(a, recipe_node)
    dot.edge(b, recipe_node)
    dot.edge(recipe_node, c)

# Render the DOT diagram to a file
dot.render('recipes_graph', format='png')

print("DOT diagram generated and saved as 'recipes_graph.png'.")
# Out:
# DOT diagram generated and saved as 'recipes_graph.png'.

# %%
def pascal_case(name):
    parts = name.split(' ')
    return ''.join(part.capitalize() for part in parts)

all_elements = []
for a, b, c in recipes:
    a_name = pascal_case(a)
    b_name = pascal_case(b)
    c_name = pascal_case(c)
    if a_name not in all_elements:
        all_elements.append(a_name)
    if b_name not in all_elements:
        all_elements.append(b_name)
    if c_name not in all_elements:
        all_elements.append(c_name)
for element in all_elements:
    print(f"  - name: {element}")
    print(f"    description: We need a description here")
    print(f"    tier: 1")
# Out:
#   - name: Water
#     description: We need a description here
#     tier: 1
#   - name: Fire
#     description: We need a description here
#     tier: 1
#   - name: Steam
#     description: We need a description here
#     tier: 1
#   - name: Earth
#     description: We need a description here
#     tier: 1
#   - name: Mud
#     description: We need a description here
#     tier: 1
#   - name: Lava
#     description: We need a description here
#     tier: 1
#   - name: Wind
#     description: We need a description here
#     tier: 1
#   - name: Dust
#     description: We need a description here
#     tier: 1
#   - name: Rain
#     description: We need a description here
#     tier: 1
#   - name: Smoke
#     description: We need a description here
#     tier: 1
#   - name: Geyser
#     description: We need a description here
#     tier: 1
#   - name: Clay
#     description: We need a description here
#     tier: 1
#   - name: Sand
#     description: We need a description here
# ...

# %%
printed_recipes_set = set()
for recipe in recipes:
    recipe_name = f"Make{pascal_case(recipe[2])}"
    if recipe_name not in printed_recipes_set:
        printed_recipes_set.add(recipe_name)
        print(f"  - name: {recipe_name}")
        print(f"    description: We need a description here")
        print(f"    a: indexed-items#{pascal_case(recipe[0])}")
        print(f"    b: indexed-items#{pascal_case(recipe[1])}")
        print(f"    c: indexed-items#{pascal_case(recipe[2])}")
# Out:
#   - name: MakeSteam
#     description: We need a description here
#     a: indexed-items#Water
#     b: indexed-items#Fire
#     c: indexed-items#Steam
#   - name: MakeMud
#     description: We need a description here
#     a: indexed-items#Water
#     b: indexed-items#Earth
#     c: indexed-items#Mud
#   - name: MakeLava
#     description: We need a description here
#     a: indexed-items#Fire
#     b: indexed-items#Earth
#     c: indexed-items#Lava
#   - name: MakeDust
#     description: We need a description here
#     a: indexed-items#Wind
#     b: indexed-items#Earth
#     c: indexed-items#Dust
#   - name: MakeRain
#     description: We need a description here
#     a: indexed-items#Water
#     b: indexed-items#Wind
#     c: indexed-items#Rain
#   - name: MakeSmoke
#     description: We need a description here
#     a: indexed-items#Fire
#     b: indexed-items#Wind
#     c: indexed-items#Smoke
#   - name: MakeGeyser
#     description: We need a description here
# ...

# %%
game_name = "elementy"
game_description = "A game in which you combine elements to create new ones."
print(f"  - name: {game_name}")
print(f"    description: {game_description}")
print(f"    items:")
for element in all_elements:
    print(f"      - indexed-items#{element}")
print(f"    recipes:")
game_recipes_set = set()
for idx, recipe in enumerate(recipes, 1):
    game_recipe_name = f"Make{pascal_case(recipe[2])}"
    if game_recipe_name not in game_recipes_set:
        game_recipes_set.add(game_recipe_name)
        print(f"      - recipes#{game_recipe_name}")
# Out:
#   - name: elementy
#     description: A game in which you combine elements to create new ones.
#     items:
#       - indexed-items#Water
#       - indexed-items#Fire
#       - indexed-items#Steam
#       - indexed-items#Earth
#       - indexed-items#Mud
#       - indexed-items#Lava
#       - indexed-items#Wind
#       - indexed-items#Dust
#       - indexed-items#Rain
#       - indexed-items#Smoke
#       - indexed-items#Geyser
#       - indexed-items#Clay
#       - indexed-items#Sand
#       - indexed-items#Plant
#       - indexed-items#Rainbow
#       - indexed-items#Storm
#       - indexed-items#Obsidian
#       - indexed-items#Ash
#       - indexed-items#Volcano
#       - indexed-items#Sandstorm
#       - indexed-items#Cloud
#       - indexed-items#Fog
#       - indexed-items#Tree
#       - indexed-items#Forest
#       - indexed-items#Seeds
#       - indexed-items#Pottery
#       - indexed-items#Brick
#       - indexed-items#Quicksand
#       - indexed-items#Glass
# ...
